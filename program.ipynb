# %%
name = str(input("what is your name: "))
last_name = str(input("what is your last name: "))
age = int(input("what is your age"))
apples = int(input ("enter number of apples: "))
print(f"your name is {name} {last_name} and your age is {age}")
# Out:
# what is your name:  darsh
# what is your last name:  mahadevia
# what is your age 20
# enter number of apples: 5
# your name is darsh mahadevia and your age is 20
